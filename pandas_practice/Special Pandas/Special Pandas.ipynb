# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Sorting/Describing Data

# %%
df1=df.sort_values(['HP',"Name"], ascending=[0,1])

df1
# Out:
#        #       Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey    Normal    NaN  255      10       10       75      135
# 121  113    Chansey    Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet   Psychic    NaN  190      33       58       33       58
# 351  321    Wailord     Water    NaN  170      90       45       90       45
# 655  594  Alomomola     Water    NaN  165      75       80       40       45
# ..   ...        ...       ...    ...  ...     ...      ...      ...      ...
# 487  439   Mime Jr.   Psychic  Fairy   20      25       45       70       90
# 186  172      Pichu  Electric    NaN   20      40       15       35       35
# 230  213    Shuckle       Bug   Rock   20      10      230       10      230
# 55    50    Diglett    Ground    NaN   10      55       25       35       45
# 316  292   Shedinja       Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# 261     55           2      False
# 121     50           1      False
# 217     33           2      False
# 351     60           3      False
# 655     65           5      False
# ..     ...         ...        ...
# 487     60           4      False
# 186     60           2      False
# 230      5           2      False
# 55      95           1      False
# 316     40           3      False
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Making changes to the data

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
#
#      Sp. Def  Speed  Generation  Legendary
# 261      135     55           2      False
# 121      105     50           1      False
# 217       58     33           2      False
# 351       45     60           3      False
# 655       45     65           5      False

# %% [markdown]
# ## Conditional Changes

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

df
# Out:
#        #       Name    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey    Normal    NaN    540  255      10       10       75
# 121  113    Chansey    Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet   Psychic    NaN    405  190      33       58       33
# 351  321    Wailord     Water    NaN    500  170      90       45       90
# 655  594  Alomomola     Water    NaN    470  165      75       80       40
# ..   ...        ...       ...    ...    ...  ...     ...      ...      ...
# 487  439   Mime Jr.   Psychic  Fairy    310   20      25       45       70
# 186  172      Pichu  Electric    NaN    205   20      40       15       35
# 230  213    Shuckle       Bug   Rock    505   20      10      230       10
# 55    50    Diglett    Ground    NaN    265   10      55       25       35
# 316  292   Shedinja       Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed Generation Legendary
# 261      135     55     Test 1    Test 2
# 121      105     50          1     False
# 217       58     33          2     False
# 351       45     60          3     False
# 655       45     65          5     False
# ..       ...    ...        ...       ...
# 487       90     60          4     False
# 186       35     60          2     False
# 230      230      5     Test 1    Test 2
# 55        45     95          1     False
# 316       30     40          3     False
#
# [800 rows x 13 columns]

# %%
df.loc[df["Name"].str.contains("Mega")]

# %%
df.loc[df["Name"].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 494  445      GarchompMega Garchomp    Dragon    Ground    700  108     170
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 426  384      RayquazaMega Rayquaza    Dragon    Flying    780  105     180
# 591  531          AudinoMega Audino    Normal     Fairy    545  103      60
# 283  260      SwampertMega Swampert     Water    Ground    635  100     150
# 268  248    TyranitarMega Tyranitar      Rock      Dark    700  100     164
# 141  130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 409  373    SalamenceMega Salamence    Dragon    Flying    700   95     145
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 511  460    AbomasnowMega Abomasnow     Grass       Ice    594   90     132
# 196  181      AmpharosMega Ampharos  Electric    Dragon    610   90      95
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 279  257      BlazikenMega Blaziken      Fire  Fighting    630   80     160
# 397  362          GlalieMega Glalie       Ice       NaN    580   80     120
# 232  214    HeracrossMega Heracross       Bug  Fighting    600   80     185
# 418  380          LatiasMega Latias    Dragon   Psychic    700   80     100
# 420  381          LatiosMega Latios    Dragon   Psychic    700   80     130
# 168  154                   Meganium     Grass       NaN    525   80      82
# 413  376    MetagrossMega Metagross     Steel   Psychic    700   80     145
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 366  334        AltariaMega Altaria    Dragon     Fairy    590   75     110
# 248  229      HoundoomMega Houndoom      Dark      Fire    600   75      90
# 224  208        SteelixMega Steelix     Steel    Ground    610   75     125
# 333  306          AggronMega Aggron     Steel       NaN    630   70     140
# 354  323      CameruptMega Camerupt      Fire    Ground    560   70     120
# 498  448        LucarioMega Lucario  Fighting     Steel    625   70     145
# 339  310    ManectricMega Manectric  Electric       NaN    575   70      75
# 275  254      SceptileMega Sceptile     Grass    Dragon    630   70     110
# 229  212          ScizorMega Scizor       Bug     Steel    600   70     150
# 349  319      SharpedoMega Sharpedo     Water      Dark    560   70     140
# 527  475        GalladeMega Gallade   Psychic  Fighting    618   68     165
# 306  282    GardevoirMega Gardevoir   Psychic     Fairy    618   68      85
# 393  359            AbsolMega Absol      Dark       NaN    565   65     150
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 476  428        LopunnyMega Lopunny    Normal  Fighting    580   65     136
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 387  354        BanetteMega Banette     Ghost       NaN    555   64     165
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 336  308      MedichamMega Medicham  Fighting   Psychic    510   60     100
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 796  719        DiancieMega Diancie      Rock     Fairy    700   50     160
# 329  303          MawileMega Mawile     Steel     Fairy    480   50     105
# 327  302        SableyeMega Sableye      Dark     Ghost    480   50      85
#
#      Defense  Sp. Atk  Sp. Def  Speed Generation Legendary
# 494      115      120       95     92     Test 1    Test 2
# 163      100      154      100    130     Test 1    Test 2
# 164       70      194      120    140     Test 1    Test 2
# 124      100       60      100    100     Test 1    Test 2
# 426      100      180      100    115     Test 1    Test 2
# 591      126       80      126     50     Test 1    Test 2
# 283      110       95      110     70     Test 1    Test 2
# 268      150       95      120     71     Test 1    Test 2
# 141      109       70      130     81     Test 1    Test 2
# 409      130      120       90    120     Test 1    Test 2
# 87       180      130       80     30     Test 1    Test 2
# 511      105      132      105     30     Test 1    Test 2
# 196      105      165      110     45     Test 1    Test 2
# 23        80      135       80    121     Test 1    Test 2
# 154       85       70       95    150     Test 1    Test 2
# 279       80      130       80    100     Test 1    Test 2
# 397       80      120       80    100     Test 1    Test 2
# 232      115       40      105     75     Test 1    Test 2
# 418      120      140      150    110     Test 1    Test 2
# 420      100      160      120    110     Test 1    Test 2
# 168      100       83      100     80     Test 1    Test 2
# 413      150      105      110    110     Test 1    Test 2
# 3        123      122      120     80     Test 1    Test 2
# 12       120      135      115     78     Test 1    Test 2
# 7        111      130       85    100     Test 1    Test 2
# 8         78      159      115    100     Test 1    Test 2
# 366      110      110      105     80     Test 1    Test 2
# 248       90      140       90    115     Test 1    Test 2
# 224      230       55       95     30     Test 1    Test 2
# 333      230       60       80     50     Test 1    Test 2
# 354      100      145      105     20     Test 1    Test 2
# 498       88      140       70    112     Test 1    Test 2
# 339       80      135       80    135     Test 1    Test 2
# 275       75      145       85    145     Test 1    Test 2
# 229      140       65      100     75     Test 1    Test 2
# 349       70      110       65    105     Test 1    Test 2
# 527       95       65      115    110     Test 1    Test 2
# 306       65      165      135    100     Test 1    Test 2
# 393       60      115       60    115     Test 1    Test 2
# 19        40       15       80    145          1     False
# 476       94       54       96    135     Test 1    Test 2
# 137      120       65       90    105     Test 1    Test 2
# 387       75       93       83     75     Test 1    Test 2
# 102       80      170       95    130     Test 1    Test 2
# 336       85       80       85    100     Test 1    Test 2
# 71        65      175       95    150     Test 1    Test 2
# 796      110      160      110    110     Test 1    Test 2
# 329      125       55       95     50          3     False
# 327      125       85      115     20          3     False

# %%
df.loc[~df["Name"].str.contains("Mega")]
# Out:
#        #       Name    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey    Normal    NaN    540  255      10       10       75
# 121  113    Chansey    Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet   Psychic    NaN    405  190      33       58       33
# 351  321    Wailord     Water    NaN    500  170      90       45       90
# 655  594  Alomomola     Water    NaN    470  165      75       80       40
# ..   ...        ...       ...    ...    ...  ...     ...      ...      ...
# 487  439   Mime Jr.   Psychic  Fairy    310   20      25       45       70
# 186  172      Pichu  Electric    NaN    205   20      40       15       35
# 230  213    Shuckle       Bug   Rock    505   20      10      230       10
# 55    50    Diglett    Ground    NaN    265   10      55       25       35
# 316  292   Shedinja       Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed Generation Legendary
# 261      135     55     Test 1    Test 2
# 121      105     50          1     False
# 217       58     33          2     False
# 351       45     60          3     False
# 655       45     65          5     False
# ..       ...    ...        ...       ...
# 487       90     60          4     False
# 186       35     60          2     False
# 230      230      5     Test 1    Test 2
# 55        45     95          1     False
# 316       30     40          3     False
#
# [751 rows x 13 columns]

# %%
import re

df.loc[df["Type 1"].str.contains("grass|fire",flags=re.I,regex=True)]
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 741  673      Gogoat  Grass       NaN    531  123     100       62       97
# 263  244       Entei   Fire       NaN    580  115     115       85       90
# 652  591   Amoonguss  Grass    Poison    464  114      85       70       85
# 559  500      Emboar   Fire  Fighting    528  110     123       65      100
# 270  250       Ho-oh   Fire    Flying    680  106     130       90      110
# ..   ...         ...    ...       ...    ...  ...     ...      ...      ...
# 4      4  Charmander   Fire       NaN    309   39      52       43       60
# 169  155   Cyndaquil   Fire       NaN    309   39      52       43       60
# 42    37      Vulpix   Fire       NaN    299   38      41       40       50
# 202  187      Hoppip  Grass    Flying    250   35      35       40       35
# 206  191     Sunkern  Grass       NaN    180   30      30       30       30
#
#      Sp. Def  Speed Generation Legendary
# 741       81     68     Test 1    Test 2
# 263       75    100     Test 1    Test 2
# 652       80     30          5     False
# 559       65     65     Test 1    Test 2
# 270      154     90     Test 1    Test 2
# ..       ...    ...        ...       ...
# 4         50     65          1     False
# 169       50     65          2     False
# 42        65     65          1     False
# 202       55     50          2     False
# 206       30     30          2     False
#
# [122 rows x 13 columns]

# %%
df.loc[df["Name"].str.contains("^pi[a-zA-Z]*",flags=re.I,regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 488  440                  Happiny    Normal       NaN    220  100       5
# 716  648  MeloettaPirouette Forme    Normal  Fighting    600  100     128
# 239  221                Piloswine       Ice    Ground    450  100     100
# 390  357                  Tropius     Grass    Flying    460   99      68
# 558  499                  Pignite      Fire  Fighting    418   90      93
# 22    18                  Pidgeot    Normal    Flying    479   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 357  326                  Grumpig   Psychic       NaN    470   80      45
# 596  536                Palpitoad     Water    Ground    384   75      65
# 502  452                  Drapion    Poison      Dark    500   70      90
# 345  316                   Gulpin    Poison       NaN    302   70      43
# 266  247                  Pupitar      Rock    Ground    410   70      84
# 463  416                Vespiquen       Bug    Flying    474   70      80
# 136  127                   Pinsir       Bug       NaN    500   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying    600   65     155
# 84    78                 Rapidash      Fire       NaN    500   65     100
# 557  498                    Tepig      Fire       NaN    308   65      63
# 76    70               Weepinbell     Grass    Poison    390   65      90
# 21    17                Pidgeotto    Normal    Flying    349   63      60
# 358  327                   Spinda    Normal       NaN    360   60      60
# 718  650                  Chespin     Grass       NaN    313   56      61
# 438  393                   Piplup     Water       NaN    314   53      51
# 578  519                   Pidove    Normal    Flying    264   50      55
# 219  204                   Pineco       Bug       NaN    290   50      65
# 490  442                Spiritomb     Ghost      Dark    485   50      92
# 13    10                 Caterpie       Bug       NaN    195   45      30
# 359  328                 Trapinch    Ground       NaN    290   45     100
# 20    16                   Pidgey    Normal    Flying    251   40      45
# 501  451                  Skorupi    Poison       Bug    330   40      50
# 181  167                 Spinarak       Bug    Poison    250   40      60
# 42    37                   Vulpix      Fire       NaN    299   38      41
# 202  187                   Hoppip     Grass    Flying    250   35      35
# 30    25                  Pikachu  Electric       NaN    320   35      55
# 189  175                   Togepi     Fairy       NaN    245   35      20
# 186  172                    Pichu  Electric       NaN    205   20      40
#
#      Defense  Sp. Atk  Sp. Def  Speed Generation Legendary
# 488        5       15       65     30          4     False
# 716       90       77       77    128     Test 1    Test 2
# 239       80       60       60     50          2     False
# 390       83       72       87     51          3     False
# 558       55       70       55     55          5     False
# 22        75       70       70    101          1     False
# 23        80      135       80    121     Test 1    Test 2
# 357       65       90      110     80          3     False
# 596       55       65       55     69          5     False
# 502      110       60       75     95          4     False
# 345       53       43       53     40          3     False
# 266       70       65       70     51          2     False
# 463      102       80      102     40          4     False
# 136      100       55       70     85          1     False
# 137      120       65       90    105     Test 1    Test 2
# 84        70       80       80    105          1     False
# 557       45       45       45     45          5     False
# 76        50       85       45     55          1     False
# 21        55       50       50     71          1     False
# 358       60       60       60     60          3     False
# 718       65       48       45     38          6     False
# 438       53       61       56     40          4     False
# 578       50       36       30     43          5     False
# 219       90       35       35     15          2     False
# 490      108       92      108     35          4     False
# 13        35       20       20     45          1     False
# 359       45       45       45     10          3     False
# 20        40       35       35     56          1     False
# 501       90       30       55     65          4     False
# 181       40       40       40     30          2     False
# 42        40       50       65     65          1     False
# 202       40       35       55     50          2     False
# 30        40       50       50     90          1     False
# 189       65       40       65     20          2     False
# 186       15       35       35     60          2     False
