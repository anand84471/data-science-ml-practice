# %% [markdown]
# # DATA MANIPULATION

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')

# %%
data1=pd.crosstab(index=titanic_train[["Survived","Pclass"]],columns=titanic_train[["Pclass","Sex"]])
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1670         blocks = form_blocks(arrays, names, axes)
# -> 1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#
# ...

# %%
titanic_train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic_train.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
titanic_train.shape
# Out:
# (156, 12)

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
# PassengerId    156 non-null int64
# Survived       156 non-null int64
# Pclass         156 non-null int64
# Name           156 non-null object
# Sex            156 non-null object
# Age            126 non-null float64
# SibSp          156 non-null int64
# Parch          156 non-null int64
# Ticket         156 non-null object
# Fare           156 non-null float64
# Cabin          31 non-null object
# Embarked       155 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.7+ KB

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
titanic_train.nunique()
# Out:
# PassengerId    156
# Survived         2
# Pclass           3
# Name           156
# Sex              2
# Age             56
# SibSp            6
# Parch            5
# Ticket         145
# Fare            93
# Cabin           28
# Embarked         3
# dtype: int64

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train[["PassengerId","Age"]
# Out:
#   File "<ipython-input-14-817899ed1087>", line 1
#     titanic_train[["PassengerId","Age"]
#                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
op=titanic_train[["PassengerId","Age"]]
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
a=titanic_train.describe(include="object")
a
# Out:
#                               Name   Sex Ticket Cabin Embarked
# count                          156   156    156    31      155
# unique                         156     2    145    28        3
# top     Goodwin, Miss. Lillian Amy  male  19950  C123        S
# freq                             1   100      2     2      110

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
qw=titanic_train.dtypes[titanic_train.dtypes=="object"].index
qw
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[qw]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
category=titanic_train.dtypes[titanic_train.dtypes == "object"].index
category
titanic_train[category]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
yt=titanic_train.select_dtypes(include="object")
yt
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
pd.options.display.max_rows=None

# %%
titanic_train.select_dtypes(include="object")
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
del titanic_train["PassengerId"]     # Remove PassengerId

# %%
sorted(titanic_train["Name"])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
#check first 15 names
sorted(titanic_train["Name"])[0:16]
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence']

# %%
titanic_train["Survived"].value_counts()
# Out:
# 0    102
# 1     54
# Name: Survived, dtype: int64

# %%
pd.Categorical(titanic_train["Survived"])
# Out:
# [0, 1, 1, 1, 0, ..., 1, 0, 0, 0, 0]
# Length: 156
# Categories (2, int64): [0, 1]

# %%
x=pd.Categorical(titanic_train["Survived"])
x=x.rename_categories(["died","survived"])
x
x.describe()
# Out:
#             counts     freqs
# categories
# died           102  0.653846
# survived        54  0.346154

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_head["Survived"]=x

# %%
titanic_train["Sur"]=x
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       Sur
# 0      0         A/5 21171   7.2500   NaN        S      died
# 1      0          PC 17599  71.2833   C85        C  survived
# 2      0  STON/O2. 3101282   7.9250   NaN        S  survived
# 3      0            113803  53.1000  C123        S  survived
# ...

# %%
titanic_train["Cabin"].nunique()
# Out:
# 28

# %%
titanic_train["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
q=titanic_train["Cabin"].astype(str)
q.unique()
# Out:
# array(['nan', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
y=np.array([i[0] for i in q])
y
# Out:
# array(['n', 'C', 'n', 'C', 'n', 'n', 'E', 'n', 'n', 'n', 'G', 'C', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'D', 'n', 'A', 'n', 'n',
#        'n', 'C', 'n', 'n', 'n', 'B', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'D', 'n', 'B', 'C', 'n', 'n', 'n', 'n', 'n', 'B', 'C', 'n', 'n',
#        'n', 'F', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'F', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'C', 'n', 'n',
#        'n', 'E', 'n', 'n', 'n', 'A', 'D', 'n', 'n', 'n', 'n', 'D', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'C', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'B', 'n', 'n', 'n', 'n', 'E', 'D', 'n', 'n', 'n', 'F', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'D', 'C', 'n', 'B', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'F', 'n', 'n', 'C', 'n', 'n', 'n', 'n'],
#       dtype='<U1')

# %%
w=titanic_train["Cabin"].astype(str)
w.unique()
# Out:
# array(['nan', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
w=titanic_train["Cabin"].astype(str)
y=np.array([a[0] for a in w])
y
# Out:
# array(['n', 'C', 'n', 'C', 'n', 'n', 'E', 'n', 'n', 'n', 'G', 'C', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'D', 'n', 'A', 'n', 'n',
#        'n', 'C', 'n', 'n', 'n', 'B', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'D', 'n', 'B', 'C', 'n', 'n', 'n', 'n', 'n', 'B', 'C', 'n', 'n',
#        'n', 'F', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'F', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'C', 'n', 'n',
#        'n', 'E', 'n', 'n', 'n', 'A', 'D', 'n', 'n', 'n', 'n', 'D', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'C', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'B', 'n', 'n', 'n', 'n', 'E', 'D', 'n', 'n', 'n', 'F', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'D', 'C', 'n', 'B', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'F', 'n', 'n', 'C', 'n', 'n', 'n', 'n'],
#       dtype='<U1')

# %%
wer=pd.Categorical(y)
wer
# Out:
# [n, C, n, C, n, ..., C, n, n, n, n]
# Length: 156
# Categories (8, object): [A, B, C, D, E, F, G, n]

# %%
titanic_train["Cabin1"]=wer
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_train["Cabin1"]=titanic_train["Cabin"].astype(str).apply(lambda x:[i[0] for i in x])
titanic_train
# Out:
#   File "<ipython-input-82-1f2ff505a498>", line 1
#     titanic_train["Cabin1"]=titanic_train["Cabin"].astype(str).apply(lambda x:x.[i[0:2] for i in x])
#                                                                                 ^
# SyntaxError: invalid syntax

# %%
wer.describe()
# Out:
#             counts     freqs
# categories
# A                2  0.012821
# B                5  0.032051
# C               10  0.064103
# D                6  0.038462
# E                3  0.019231
# F                4  0.025641
# G                1  0.006410
# n              125  0.801282

# %%
c=pd.Series([1,None,4,None,5])
c
# Out:
# 0    1.0
# 1    NaN
# 2    4.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
c.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-64c6a4f7e094> in <module>
# ----> 1 c.isnull()
#
# NameError: name 'c' is not defined

# %%
titanic_train["Age"].isnull()==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
# 30     False
# 31      True
# 32      True
# 33     False
# 34     False
# 35     False
# 36      True
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42      True
# 43     False
# 44     False
# 45      True
# 46      True
# 47      True
# 48      True
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55      True
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64      True
# 65      True
# ...

# %%
np.where(titanic_train["Age"].isnull()==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
missing=np.where(titanic_train["Age"].isnull()==True)

# %%
len(missing[0])
# Out:
# 30

# %% [markdown]
# # use of LOC function

# %%
titanic_train.loc[missing]
# Out:
#      Survived  Pclass                                            Name     Sex  \
# 5           0       3                                Moran, Mr. James    male
# 17          1       2                    Williams, Mr. Charles Eugene    male
# 19          1       3                         Masselmani, Mrs. Fatima  female
# 26          0       3                         Emir, Mr. Farred Chehab    male
# 28          1       3                   O'Dwyer, Miss. Ellen "Nellie"  female
# 29          0       3                             Todoroff, Mr. Lalio    male
# 31          1       1  Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 32          1       3                        Glynn, Miss. Mary Agatha  female
# 36          1       3                                Mamee, Mr. Hanna    male
# 42          0       3                             Kraeff, Mr. Theodor    male
# 45          0       3                        Rogers, Mr. William John    male
# ...

# %%
max_fare=np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))
max_fare
# Out:
# (array([27, 88], dtype=int64),)

# %%
max_index=titanic_train.loc[max_fare]
max_index
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked       Sur  family
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S      died       5
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S  survived       5

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       Sur
# 0      0         A/5 21171   7.2500   NaN        S      died
# 1      0          PC 17599  71.2833   C85        C  survived
# 2      0  STON/O2. 3101282   7.9250   NaN        S  survived
# 3      0            113803  53.1000  C123        S  survived
# ...

# %%
titanic_train["family"]=titanic_train["SibSp"] + titanic_train["Parch"]
titanic_train.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %%
most_family=np.where(titanic_train["family"]==max(titanic_train["family"]))
most_family
# Out:
# (array([59, 71], dtype=int64),)

# %%
titanic_train.iloc[[59,71]]
# Out:
#     Survived  Pclass                                Name     Sex   Age  SibSp  \
# 59         0       3  Goodwin, Master. William Frederick    male  11.0      5
# 71         0       3          Goodwin, Miss. Lillian Amy  female  16.0      5
#
#     Parch   Ticket  Fare Cabin Embarked Survived1  family
# 59      2  CA 2144  46.9   NaN        S      died       7
# 71      2  CA 2144  46.9   NaN        S      died       7

# %%
titanic_train["Ticket"][0:16]      # Check the first 15 tickets
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# 15              248706
# Name: Ticket, dtype: object

# %%
titanic_train["Ticket"].describe()
# Out:
# count            156
# unique           145
# top       W./C. 6608
# freq               2
# Name: Ticket, dtype: object

# %%
del titanic_train["Ticket"]        # Remove Ticket

# %%
titanic_train["Cabin"][0:15]       # Check the first 15 tickets
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3     C123
# 4      NaN
# 5      NaN
# 6      E46
# 7      NaN
# 8      NaN
# 9      NaN
# 10      G6
# 11    C103
# 12     NaN
# 13     NaN
# 14     NaN
# Name: Cabin, dtype: object

# %%
titanic_train["Cabin"].describe()  # Check number of unique cabins
# Out:
# count              31
# unique             28
# top       C23 C25 C27
# freq                2
# Name: Cabin, dtype: object

# %%
a=titanic_train.columns

# %%
b=sorted(a)

# %%
b
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Survived1',
#  'family']

# %%
titanic_train[b]
# Out:
#        Age        Cabin Embarked      Fare  \
# 0    22.00          NaN        S    7.2500
# 1    38.00          C85        C   71.2833
# 2    26.00          NaN        S    7.9250
# 3    35.00         C123        S   53.1000
# 4    35.00          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6    54.00          E46        S   51.8625
# 7     2.00          NaN        S   21.0750
# 8    27.00          NaN        S   11.1333
# 9    14.00          NaN        C   30.0708
# 10    4.00           G6        S   16.7000
# 11   58.00         C103        S   26.5500
# 12   20.00          NaN        S    8.0500
# 13   39.00          NaN        S   31.2750
# 14   14.00          NaN        S    7.8542
# 15   55.00          NaN        S   16.0000
# 16    2.00          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18   31.00          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20   35.00          NaN        S   26.0000
# ...
